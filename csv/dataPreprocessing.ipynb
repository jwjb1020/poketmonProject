# %%
import pandas as pd
#csv 파일 경로
csv_path = "../csv/poketmon_data.csv"

#csv 파일 읽어오기
df = pd.read_csv("../csv/poketmon_data.csv", encoding="utf-8")

df
# Out:
#         no    name     figure type1 type2  sex  height   weight    class  \
# 0        1    이상해씨        NaN     풀     독  남/여    0.7m    6.9kg    씨앗포켓몬
# 1        2    이상해풀        NaN     풀     독  남/여    1.0m   13.0kg    씨앗포켓몬
# 2        3    이상해꽃        NaN     풀     독  남/여    2.0m  100.0kg    씨앗포켓몬
# 3        3  메가이상해꽃        NaN     풀     독  남/여    2.4m  155.5kg    씨앗포켓몬
# 4        3    이상해꽃  거다이맥스의 모습     풀     독  남/여  24.0m~  ???.?kg    씨앗포켓몬
# ...    ...     ...        ...   ...   ...  ...     ...      ...      ...
# 1224  1008    미라이돈        NaN    전기   드래곤   불명    3.5m  240.0kg  패러독스포켓몬
# 1225   999     모으령        도보폼   고스트   NaN   불명    0.1m    0.1kg  보물찾기포켓몬
# 1226   809     멜메탈  거다이맥스의 모습    강철   NaN   불명  25.0m~  ???.?kg    너트포켓몬
# 1227  1009  굽이치는물결        NaN     물   드래곤   불명    3.5m  280.0kg  패러독스포켓몬
# 1228  1010    무쇠잎새        NaN     풀   에스퍼   불명    1.5m  125.0kg  패러독스포켓몬
#
#       char1 char2  image
# 0        심록          NaN
# 1        심록          NaN
# ...
